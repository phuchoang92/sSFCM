# %% [markdown]
# # **Dataset Preparation & Preprocessing**

# %% [markdown]
# ## Load Data

# %%
import pandas as pd
data = pd.read_csv('resources/iris.data', header = None)
data = data.select_dtypes(include=["float64", "int64"])
index= data.index.to_numpy(dtype="int64")
data
# Out:
#        0    1    2    3
# 0    5.1  3.5  1.4  0.2
# 1    4.9  3.0  1.4  0.2
# 2    4.7  3.2  1.3  0.2
# 3    4.6  3.1  1.5  0.2
# 4    5.0  3.6  1.4  0.2
# ..   ...  ...  ...  ...
# 145  6.7  3.0  5.2  2.3
# 146  6.3  2.5  5.0  1.9
# 147  6.5  3.0  5.2  2.0
# 148  6.2  3.4  5.4  2.3
# 149  5.9  3.0  5.1  1.8
#
# [150 rows x 4 columns]

# %%
import numpy as np
X = np.array(data)
n = X.shape[0]
p = X.shape[1]
print(X.shape)
X
# Out:
# (150, 4)
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.5, 4.2, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5. , 3.2, 1.2, 0.2],
#        [5.5, 3.5, 1.3, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [4.4, 3. , 1.3, 0.2],
#        [5.1, 3.4, 1.5, 0.2],
#        [5. , 3.5, 1.3, 0.3],
#        [4.5, 2.3, 1.3, 0.3],
#        [4.4, 3.2, 1.3, 0.2],
#        [5. , 3.5, 1.6, 0.6],
#        [5.1, 3.8, 1.9, 0.4],
#        [4.8, 3. , 1.4, 0.3],
#        [5.1, 3.8, 1.6, 0.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [5. , 3.3, 1.4, 0.2],
#        [7. , 3.2, 4.7, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.5, 2.3, 4. , 1.3],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [4.9, 2.4, 3.3, 1. ],
#        [6.6, 2.9, 4.6, 1.3],
#        [5.2, 2.7, 3.9, 1.4],
#        [5. , 2. , 3.5, 1. ],
#        [5.9, 3. , 4.2, 1.5],
#        [6. , 2.2, 4. , 1. ],
#        [6.1, 2.9, 4.7, 1.4],
#        [5.6, 2.9, 3.6, 1.3],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.6, 3. , 4.5, 1.5],
#        [5.8, 2.7, 4.1, 1. ],
#        [6.2, 2.2, 4.5, 1.5],
#        [5.6, 2.5, 3.9, 1.1],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.1, 2.8, 4. , 1.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.4, 2.9, 4.3, 1.3],
#        [6.6, 3. , 4.4, 1.4],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.7, 3. , 5. , 1.7],
#        [6. , 2.9, 4.5, 1.5],
#        [5.7, 2.6, 3.5, 1. ],
#        [5.5, 2.4, 3.8, 1.1],
#        [5.5, 2.4, 3.7, 1. ],
#        [5.8, 2.7, 3.9, 1.2],
#        [6. , 2.7, 5.1, 1.6],
#        [5.4, 3. , 4.5, 1.5],
#        [6. , 3.4, 4.5, 1.6],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.6, 3. , 4.1, 1.3],
#        [5.5, 2.5, 4. , 1.3],
#        [5.5, 2.6, 4.4, 1.2],
#        [6.1, 3. , 4.6, 1.4],
#        [5.8, 2.6, 4. , 1.2],
#        [5. , 2.3, 3.3, 1. ],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.7, 3. , 4.2, 1.2],
#        [5.7, 2.9, 4.2, 1.3],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.1, 2.5, 3. , 1.1],
#        [5.7, 2.8, 4.1, 1.3],
#        [6.3, 3.3, 6. , 2.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [7.1, 3. , 5.9, 2.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.5, 3. , 5.8, 2.2],
#        [7.6, 3. , 6.6, 2.1],
#        [4.9, 2.5, 4.5, 1.7],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.7, 2.5, 5.8, 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.5, 3.2, 5.1, 2. ],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.8, 3. , 5.5, 2.1],
#        [5.7, 2.5, 5. , 2. ],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.5, 3. , 5.5, 1.8],
#        [7.7, 3.8, 6.7, 2.2],
#        [7.7, 2.6, 6.9, 2.3],
#        [6. , 2.2, 5. , 1.5],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.6, 2.8, 4.9, 2. ],
#        [7.7, 2.8, 6.7, 2. ],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.7, 3.3, 5.7, 2.1],
#        [7.2, 3.2, 6. , 1.8],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.1, 3. , 4.9, 1.8],
#        [6.4, 2.8, 5.6, 2.1],
#        [7.2, 3. , 5.8, 1.6],
#        [7.4, 2.8, 6.1, 1.9],
#        [7.9, 3.8, 6.4, 2. ],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.1, 2.6, 5.6, 1.4],
#        [7.7, 3. , 6.1, 2.3],
#        [6.3, 3.4, 5.6, 2.4],
#        [6.4, 3.1, 5.5, 1.8],
#        [6. , 3. , 4.8, 1.8],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.7, 3.1, 5.6, 2.4],
#        [6.9, 3.1, 5.1, 2.3],
#        [5.8, 2.7, 5.1, 1.9],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.7, 3. , 5.2, 2.3],
#        [6.3, 2.5, 5. , 1.9],
#        [6.5, 3. , 5.2, 2. ],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.9, 3. , 5.1, 1.8]])

# %% [markdown]
# ## Generate U_ngang , V

# %%
from random import random
import random
c=3  #value of c 
k1 = 50
index_x_giamsat = random.sample(range(n),k1)# CHọn k1 vector x từ n vector x ban đầu  
index_x_giamsat = np.sort(index_x_giamsat)
print(index_x_giamsat)
U_ngang = np.zeros((n,c))
for i in range(k1):
    c1= random.randint(0,c-1)                    #Chọn vị trí cụm giám sát
    U_ngang[index_x_giamsat[i]][c1] = 0.5     
sum_i = sum(U_ngang.T)
#Maxtrix U_ngang
for i in range(n):
    print(str(i) +" : "+ str(U_ngang[i]))
# Out:
# [  6   7  11  13  17  20  22  28  30  31  34  37  38  40  41  43  48  55
#   63  64  66  68  71  76  77  78  81  85  95 101 105 106 107 108 109 112
#  113 115 118 122 123 125 126 128 131 132 133 137 145 147]
# 0 : [0. 0. 0.]
# 1 : [0. 0. 0.]
# 2 : [0. 0. 0.]
# 3 : [0. 0. 0.]
# 4 : [0. 0. 0.]
# 5 : [0. 0. 0.]
# 6 : [0.5 0.  0. ]
# 7 : [0.  0.5 0. ]
# 8 : [0. 0. 0.]
# 9 : [0. 0. 0.]
# 10 : [0. 0. 0.]
# 11 : [0.  0.  0.5]
# 12 : [0. 0. 0.]
# 13 : [0.5 0.  0. ]
# 14 : [0. 0. 0.]
# 15 : [0. 0. 0.]
# 16 : [0. 0. 0.]
# 17 : [0.  0.5 0. ]
# 18 : [0. 0. 0.]
# 19 : [0. 0. 0.]
# 20 : [0.  0.5 0. ]
# 21 : [0. 0. 0.]
# 22 : [0.5 0.  0. ]
# 23 : [0. 0. 0.]
# 24 : [0. 0. 0.]
# 25 : [0. 0. 0.]
# 26 : [0. 0. 0.]
# 27 : [0. 0. 0.]
# 28 : [0.5 0.  0. ]
# 29 : [0. 0. 0.]
# 30 : [0.  0.5 0. ]
# 31 : [0.  0.5 0. ]
# 32 : [0. 0. 0.]
# 33 : [0. 0. 0.]
# 34 : [0.  0.  0.5]
# 35 : [0. 0. 0.]
# 36 : [0. 0. 0.]
# 37 : [0.  0.5 0. ]
# 38 : [0.5 0.  0. ]
# 39 : [0. 0. 0.]
# 40 : [0.  0.  0.5]
# 41 : [0.  0.5 0. ]
# 42 : [0. 0. 0.]
# 43 : [0.  0.  0.5]
# 44 : [0. 0. 0.]
# 45 : [0. 0. 0.]
# 46 : [0. 0. 0.]
# 47 : [0. 0. 0.]
# 48 : [0.  0.  0.5]
# 49 : [0. 0. 0.]
# 50 : [0. 0. 0.]
# 51 : [0. 0. 0.]
# 52 : [0. 0. 0.]
# 53 : [0. 0. 0.]
# 54 : [0. 0. 0.]
# 55 : [0.  0.  0.5]
# 56 : [0. 0. 0.]
# 57 : [0. 0. 0.]
# 58 : [0. 0. 0.]
# 59 : [0. 0. 0.]
# 60 : [0. 0. 0.]
# 61 : [0. 0. 0.]
# 62 : [0. 0. 0.]
# 63 : [0.5 0.  0. ]
# 64 : [0.  0.5 0. ]
# 65 : [0. 0. 0.]
# 66 : [0.  0.  0.5]
# 67 : [0. 0. 0.]
# 68 : [0.  0.5 0. ]
# 69 : [0. 0. 0.]
# 70 : [0. 0. 0.]
# 71 : [0.  0.  0.5]
# 72 : [0. 0. 0.]
# 73 : [0. 0. 0.]
# 74 : [0. 0. 0.]
# 75 : [0. 0. 0.]
# 76 : [0.5 0.  0. ]
# 77 : [0.5 0.  0. ]
# 78 : [0.5 0.  0. ]
# 79 : [0. 0. 0.]
# 80 : [0. 0. 0.]
# 81 : [0.  0.5 0. ]
# 82 : [0. 0. 0.]
# 83 : [0. 0. 0.]
# 84 : [0. 0. 0.]
# 85 : [0.5 0.  0. ]
# 86 : [0. 0. 0.]
# 87 : [0. 0. 0.]
# 88 : [0. 0. 0.]
# 89 : [0. 0. 0.]
# 90 : [0. 0. 0.]
# 91 : [0. 0. 0.]
# 92 : [0. 0. 0.]
# 93 : [0. 0. 0.]
# 94 : [0. 0. 0.]
# 95 : [0.  0.  0.5]
# 96 : [0. 0. 0.]
# 97 : [0. 0. 0.]
# 98 : [0. 0. 0.]
# 99 : [0. 0. 0.]
# 100 : [0. 0. 0.]
# 101 : [0.  0.  0.5]
# 102 : [0. 0. 0.]
# 103 : [0. 0. 0.]
# 104 : [0. 0. 0.]
# 105 : [0.5 0.  0. ]
# 106 : [0.5 0.  0. ]
# 107 : [0.  0.  0.5]
# 108 : [0.  0.  0.5]
# 109 : [0.  0.5 0. ]
# 110 : [0. 0. 0.]
# 111 : [0. 0. 0.]
# 112 : [0.5 0.  0. ]
# 113 : [0.  0.  0.5]
# 114 : [0. 0. 0.]
# 115 : [0.  0.  0.5]
# 116 : [0. 0. 0.]
# 117 : [0. 0. 0.]
# 118 : [0.5 0.  0. ]
# 119 : [0. 0. 0.]
# 120 : [0. 0. 0.]
# 121 : [0. 0. 0.]
# 122 : [0.  0.5 0. ]
# 123 : [0.5 0.  0. ]
# 124 : [0. 0. 0.]
# 125 : [0.5 0.  0. ]
# 126 : [0.  0.  0.5]
# 127 : [0. 0. 0.]
# 128 : [0.  0.5 0. ]
# 129 : [0. 0. 0.]
# 130 : [0. 0. 0.]
# 131 : [0.  0.5 0. ]
# 132 : [0.5 0.  0. ]
# 133 : [0.5 0.  0. ]
# 134 : [0. 0. 0.]
# 135 : [0. 0. 0.]
# 136 : [0. 0. 0.]
# 137 : [0.  0.  0.5]
# 138 : [0. 0. 0.]
# 139 : [0. 0. 0.]
# 140 : [0. 0. 0.]
# 141 : [0. 0. 0.]
# 142 : [0. 0. 0.]
# 143 : [0. 0. 0.]
# 144 : [0. 0. 0.]
# 145 : [0.  0.  0.5]
# 146 : [0. 0. 0.]
# 147 : [0.5 0.  0. ]
# 148 : [0. 0. 0.]
# 149 : [0. 0. 0.]

# %%
#Maxtrix V sinh ngau nhien
V = np.random.rand(c,p)
V_truoc = V
V
# Out:
# array([[0.92656583, 0.38909217, 0.27380405, 0.76441456],
#        [0.1024301 , 0.91797819, 0.68947006, 0.89280196],
#        [0.51580174, 0.85640471, 0.28509312, 0.2406713 ]])

# %% [markdown]
# ## Function 4 ,6

# %%
# Tinh d_ki (trong cong thuc 6)
def d_ki(k, i):
    kq = sum(  pow(X[k] - V[i], 2) )
    return kq     
d_ki(0,0)
# Out:
# 28.682181450830726

# %%
#Cong thuc so 6

U = np.zeros((n,c))  # Maxtrix U


def cong_thuc_6(m):
    
    Z = np.zeros((n,c))
    #tu day suy ra U = U_ngang + Z ta tinh Z

    D = np.zeros((n,c))
    for k in range(n):
        for i in range(c):
            D[k][i] = pow(d_ki(k,i),1/(1-m))    
        D[k] = D[k]/sum(D[k])    
     

    #Z = (1/d_ki)^1/m-1z = np.array (i = 1 ,c)
    for i in range(n) :
        Z[i] = (1 - sum_i[i])*D[i]
        
    return U_ngang+Z  # tuc la U

# %%
def cong_thuc_4(m):
    global V, V_truoc
    V_truoc = V
    print("V_truoc:")
    print(V_truoc)
    
    V_temp = np.zeros((c,p))
    U_temp = abs(U - U_ngang)
    U_temp = pow(U_temp,m)
    for i in range(c):
        tu_so = np.zeros(p)
        for k in range(n):
           tu_so +=U_temp[k][i] * X[k] 
        V_temp[i] = tu_so/ sum((U_temp.T)[i])
    print("V_sau:")
    print(V_temp)
    return V_temp

# %%
def thuat_toan(epsilon,m):
    global U,V
    Epsilon = np.zeros((c,p)) + epsilon
    i=1
    while True:
        print("-----------------------\nChay lan "+ str(i)+"\n")
        i+=1
        U= cong_thuc_6(m)
        V= cong_thuc_4(m)
        delta_V = abs(V- V_truoc)
        ktra = np.less_equal(delta_V, Epsilon)
        if (np.all(ktra)):
            break
    print("\n------------------------------------\nKetqua\n")
    print(V)
    return

# %% [markdown]
# # **Main**

# %%
thuat_toan(1e-6, 2)
# Out:
# -----------------------
# Chay lan 1
#
# V_truoc:
# [[0.92656583 0.38909217 0.27380405 0.76441456]
#  [0.1024301  0.91797819 0.68947006 0.89280196]
#  [0.51580174 0.85640471 0.28509312 0.2406713 ]]
# V_sau:
# [[5.8123039  3.06103664 3.69162109 1.17133128]
#  [5.8599489  3.05444353 3.81262776 1.22443219]
#  [5.79625296 3.07654247 3.63742851 1.14830339]]
# -----------------------
# Chay lan 2
#
# V_truoc:
# [[5.8123039  3.06103664 3.69162109 1.17133128]
#  [5.8599489  3.05444353 3.81262776 1.22443219]
#  [5.79625296 3.07654247 3.63742851 1.14830339]]
# V_sau:
# [[5.79166926 3.07164124 3.63495571 1.14884766]
#  [5.92782689 3.02264632 4.00218059 1.29816181]
#  [5.72839625 3.10290161 3.45321078 1.0751726 ]]
# -----------------------
# Chay lan 3
#
# V_truoc:
# [[5.79166926 3.07164124 3.63495571 1.14884766]
#  [5.92782689 3.02264632 4.00218059 1.29816181]
#  [5.72839625 3.10290161 3.45321078 1.0751726 ]]
# V_sau:
# [[5.72329425 3.08744354 3.4634542  1.07905537]
#  [6.07335335 2.96499766 4.3998176  1.45819229]
#  [5.51068806 3.18640408 2.86930346 0.83388509]]
# -----------------------
# Chay lan 4
#
# V_truoc:
# [[5.72329425 3.08744354 3.4634542  1.07905537]
#  [6.07335335 2.96499766 4.3998176  1.45819229]
#  [5.51068806 3.18640408 2.86930346 0.83388509]]
# V_sau:
# [[5.59573997 2.98548094 3.3316675  1.00848546]
#  [6.26366108 2.93574286 4.83101619 1.64597846]
#  [5.15165033 3.36144699 1.86221267 0.40840769]]
# -----------------------
# Chay lan 5
#
# V_truoc:
# [[5.59573997 2.98548094 3.3316675  1.00848546]
#  [6.26366108 2.93574286 4.83101619 1.64597846]
#  [5.15165033 3.36144699 1.86221267 0.40840769]]
# V_sau:
# [[5.58166937 2.62864211 3.85290306 1.19380685]
#  [6.39038451 2.95268564 5.07735299 1.77362586]
#  [5.0492543  3.44484897 1.521075   0.26099198]]
# -----------------------
# Chay lan 6
#
# V_truoc:
# [[5.58166937 2.62864211 3.85290306 1.19380685]
#  [6.39038451 2.95268564 5.07735299 1.77362586]
#  [5.0492543  3.44484897 1.521075   0.26099198]]
# V_sau:
# [[5.64607793 2.63132621 4.02077327 1.23908521]
#  [6.49220417 2.99134441 5.24079683 1.86898494]
#  [5.04113995 3.45146856 1.49182736 0.24950472]]
# -----------------------
# Chay lan 7
#
# V_truoc:
# [[5.64607793 2.63132621 4.02077327 1.23908521]
#  [6.49220417 2.99134441 5.24079683 1.86898494]
#  [5.04113995 3.45146856 1.49182736 0.24950472]]
# V_sau:
# [[5.7029669  2.66129068 4.09472328 1.26493424]
#  [6.55087105 3.01454251 5.337958   1.92688994]
#  [5.04018579 3.45041579 1.49155973 0.24959201]]
# -----------------------
# Chay lan 8
#
# V_truoc:
# [[5.7029669  2.66129068 4.09472328 1.26493424]
#  [6.55087105 3.01454251 5.337958   1.92688994]
#  [5.04018579 3.45041579 1.49155973 0.24959201]]
# V_sau:
# [[5.74516113 2.68241596 4.1445449  1.28500464]
#  [6.58894015 3.02941228 5.40076222 1.96350505]
#  [5.03981194 3.44921415 1.49283719 0.25021316]]
# -----------------------
# Chay lan 9
#
# V_truoc:
# [[5.74516113 2.68241596 4.1445449  1.28500464]
#  [6.58894015 3.02941228 5.40076222 1.96350505]
#  [5.03981194 3.44921415 1.49283719 0.25021316]]
# V_sau:
# [[5.775599   2.69696208 4.1809497  1.30063741]
#  [6.61534258 3.03975472 5.44301482 1.98773274]
#  [5.03961496 3.44823828 1.49408852 0.25079919]]
# -----------------------
# Chay lan 10
#
# V_truoc:
# [[5.775599   2.69696208 4.1809497  1.30063741]
#  [6.61534258 3.03975472 5.44301482 1.98773274]
#  [5.03961496 3.44823828 1.49408852 0.25079919]]
# V_sau:
# [[5.797328   2.70709502 4.20757399 1.31250208]
#  [6.63407643 3.0471077  5.47207074 2.0041901 ]
#  [5.03950403 3.44747315 1.49514928 0.25128932]]
# -----------------------
# Chay lan 11
#
# V_truoc:
# [[5.797328   2.70709502 4.20757399 1.31250208]
#  [6.63407643 3.0471077  5.47207074 2.0041901 ]
#  [5.03950403 3.44747315 1.49514928 0.25128932]]
# V_sau:
# [[5.81272082 2.714173   4.22682812 1.32128995]
#  [6.64740463 3.05233403 5.49223208 2.01549917]
#  [5.03943965 3.44688778 1.49599624 0.25167721]]
# -----------------------
# Chay lan 12
#
# V_truoc:
# [[5.81272082 2.714173   4.22682812 1.32128995]
#  [6.64740463 3.05233403 5.49223208 2.01549917]
#  [5.03943965 3.44688778 1.49599624 0.25167721]]
# V_sau:
# [[5.82355333 2.71910995 4.24059321 1.32767381]
#  [6.65684477 3.05602655 5.50624755 2.0233001 ]
#  [5.03940166 3.44645042 1.49664601 0.2519729 ]]
# -----------------------
# Chay lan 13
#
# V_truoc:
# [[5.82355333 2.71910995 4.24059321 1.32767381]
#  [6.65684477 3.05602655 5.50624755 2.0233001 ]
#  [5.03940166 3.44645042 1.49664601 0.2519729 ]]
# V_sau:
# [[5.83113466 2.72254484 4.25033946 1.33224319]
#  [6.6634906  3.05861849 5.51598032 2.02868446]
#  [5.03937889 3.44613024 1.49713002 0.25219216]]
# -----------------------
# Chay lan 14
#
# V_truoc:
# [[5.83113466 2.72254484 4.25033946 1.33224319]
#  [6.6634906  3.05861849 5.51598032 2.02868446]
#  [5.03937889 3.44613024 1.49713002 0.25219216]]
# V_sau:
# [[5.83641742 2.72492878 4.25718802 1.33547794]
#  [6.66814307 3.06042802 5.52272676 2.0323994 ]
#  [5.03936499 3.44589965 1.4974827  0.25235142]]
# -----------------------
# Chay lan 15
#
# V_truoc:
# [[5.83641742 2.72492878 4.25718802 1.33547794]
#  [6.66814307 3.06042802 5.52272676 2.0323994 ]
#  [5.03936499 3.44589965 1.4974827  0.25235142]]
# V_sau:
# [[5.84008624 2.72657991 4.26197288 1.33774948]
#  [6.67138533 3.06168614 5.52739511 2.03496114]
#  [5.03935633 3.44573565 1.49773554 0.25246533]]
# -----------------------
# Chay lan 16
#
# V_truoc:
# [[5.84008624 2.72657991 4.26197288 1.33774948]
#  [6.67138533 3.06168614 5.52739511 2.03496114]
#  [5.03935633 3.44573565 1.49773554 0.25246533]]
# V_sau:
# [[5.84262791 2.72772167 4.2653018  1.33933536]
#  [6.67363705 3.06255829 5.53062099 2.03672686]
#  [5.03935083 3.44562009 1.49791468 0.25254591]]
# -----------------------
# Chay lan 17
#
# V_truoc:
# [[5.84262791 2.72772167 4.2653018  1.33933536]
#  [6.67363705 3.06255829 5.53062099 2.03672686]
#  [5.03935083 3.44562009 1.49791468 0.25254591]]
# V_sau:
# [[5.84438557 2.72851025 4.26761074 1.34043798]
#  [6.6751969  3.06316164 5.53284781 2.03794351]
#  [5.03934726 3.44553922 1.49804052 0.25260245]]
# -----------------------
# Chay lan 18
#
# V_truoc:
# [[5.84438557 2.72851025 4.26761074 1.34043798]
#  [6.6751969  3.06316164 5.53284781 2.03794351]
#  [5.03934726 3.44553922 1.49804052 0.25260245]]
# V_sau:
# [[5.84559952 2.72905441 4.26920873 1.34120236]
#  [6.67627552 3.06357842 5.53438384 2.03878165]
#  [5.03934492 3.44548289 1.49812839 0.2526419 ]]
# -----------------------
# Chay lan 19
#
# V_truoc:
# [[5.84559952 2.72905441 4.26920873 1.34120236]
#  [6.67627552 3.06357842 5.53438384 2.03878165]
#  [5.03934492 3.44548289 1.49812839 0.2526419 ]]
# V_sau:
# [[5.84643718 2.72942968 4.270313   1.34173116]
#  [6.67702043 3.06386604 5.53544281 2.03935897]
#  [5.03934336 3.44544379 1.49818949 0.25266932]]
# -----------------------
# Chay lan 20
#
# V_truoc:
# [[5.84643718 2.72942968 4.270313   1.34173116]
#  [6.67702043 3.06386604 5.53544281 2.03935897]
#  [5.03934336 3.44544379 1.49818949 0.25266932]]
# V_sau:
# [[5.84701484 2.72968837 4.27107526 1.34209648]
#  [6.67753442 3.0640644  5.53617262 2.03975658]
#  [5.03934231 3.44541672 1.49823184 0.25268832]]
# -----------------------
# Chay lan 21
#
# V_truoc:
# [[5.84701484 2.72968837 4.27107526 1.34209648]
#  [6.67753442 3.0640644  5.53617262 2.03975658]
#  [5.03934231 3.44541672 1.49823184 0.25268832]]
# V_sau:
# [[5.84741301 2.72986662 4.27160105 1.3423486 ]
#  [6.67788884 3.06420113 5.53667545 2.04003042]
#  [5.0393416  3.44539801 1.49826115 0.25270146]]
# -----------------------
# Chay lan 22
#
# V_truoc:
# [[5.84741301 2.72986662 4.27160105 1.3423486 ]
#  [6.67788884 3.06420113 5.53667545 2.04003042]
#  [5.0393416  3.44539801 1.49826115 0.25270146]]
# V_sau:
# [[5.84768738 2.72998944 4.27196353 1.34252248]
#  [6.67813314 3.06429535 5.53702185 2.040219  ]
#  [5.03934111 3.44538509 1.49828139 0.25271053]]
# -----------------------
# Chay lan 23
#
# V_truoc:
# [[5.84768738 2.72998944 4.27196353 1.34252248]
#  [6.67813314 3.06429535 5.53702185 2.040219  ]
#  [5.03934111 3.44538509 1.49828139 0.25271053]]
# V_sau:
# [[5.84787641 2.73007403 4.27221335 1.34264234]
#  [6.67830147 3.06436026 5.53726044 2.04034887]
#  [5.03934078 3.44537617 1.49829536 0.25271679]]
# -----------------------
# Chay lan 24
#
# V_truoc:
# [[5.84787641 2.73007403 4.27221335 1.34264234]
#  [6.67830147 3.06436026 5.53726044 2.04034887]
#  [5.03934078 3.44537617 1.49829536 0.25271679]]
# V_sau:
# [[5.84800662 2.7301323  4.27238546 1.34272494]
#  [6.67841744 3.06440497 5.53742477 2.0404383 ]
#  [5.03934056 3.44537003 1.49830499 0.25272111]]
# -----------------------
# Chay lan 25
#
# V_truoc:
# [[5.84800662 2.7301323  4.27238546 1.34272494]
#  [6.67841744 3.06440497 5.53742477 2.0404383 ]
#  [5.03934056 3.44537003 1.49830499 0.25272111]]
# V_sau:
# [[5.8480963  2.73017243 4.27250403 1.34278185]
#  [6.67849732 3.06443577 5.53753794 2.04049988]
#  [5.0393404  3.44536579 1.49831164 0.25272409]]
# -----------------------
# Chay lan 26
#
# V_truoc:
# [[5.8480963  2.73017243 4.27250403 1.34278185]
#  [6.67849732 3.06443577 5.53753794 2.04049988]
#  [5.0393404  3.44536579 1.49831164 0.25272409]]
# V_sau:
# [[5.84815807 2.73020007 4.2725857  1.34282105]
#  [6.67855234 3.06445698 5.53761588 2.04054229]
#  [5.0393403  3.44536288 1.49831621 0.25272614]]
# -----------------------
# Chay lan 27
#
# V_truoc:
# [[5.84815807 2.73020007 4.2725857  1.34282105]
#  [6.67855234 3.06445698 5.53761588 2.04054229]
#  [5.0393403  3.44536288 1.49831621 0.25272614]]
# V_sau:
# [[5.8482006  2.73021911 4.27264195 1.34284805]
#  [6.67859023 3.06447159 5.53766955 2.04057149]
#  [5.03934022 3.44536087 1.49831937 0.25272756]]
# -----------------------
# Chay lan 28
#
# V_truoc:
# [[5.8482006  2.73021911 4.27264195 1.34284805]
#  [6.67859023 3.06447159 5.53766955 2.04057149]
#  [5.03934022 3.44536087 1.49831937 0.25272756]]
# V_sau:
# [[5.8482299  2.73023221 4.27268068 1.34286664]
#  [6.67861633 3.06448165 5.53770651 2.0405916 ]
#  [5.03934017 3.44535948 1.49832154 0.25272853]]
# -----------------------
# Chay lan 29
#
# V_truoc:
# [[5.8482299  2.73023221 4.27268068 1.34286664]
#  [6.67861633 3.06448165 5.53770651 2.0405916 ]
#  [5.03934017 3.44535948 1.49832154 0.25272853]]
# V_sau:
# [[5.84825007 2.73024124 4.27270736 1.34287945]
#  [6.6786343  3.06448858 5.53773196 2.04060545]
#  [5.03934014 3.44535853 1.49832303 0.2527292 ]]
# -----------------------
# Chay lan 30
#
# V_truoc:
# [[5.84825007 2.73024124 4.27270736 1.34287945]
#  [6.6786343  3.06448858 5.53773196 2.04060545]
#  [5.03934014 3.44535853 1.49832303 0.2527292 ]]
# V_sau:
# [[5.84826396 2.73024745 4.27272573 1.34288827]
#  [6.67864668 3.06449335 5.53774949 2.04061498]
#  [5.03934012 3.44535787 1.49832406 0.25272966]]
# -----------------------
# Chay lan 31
#
# V_truoc:
# [[5.84826396 2.73024745 4.27272573 1.34288827]
#  [6.67864668 3.06449335 5.53774949 2.04061498]
#  [5.03934012 3.44535787 1.49832406 0.25272966]]
# V_sau:
# [[5.84827353 2.73025173 4.27273838 1.34289434]
#  [6.6786552  3.06449663 5.53776156 2.04062155]
#  [5.0393401  3.44535742 1.49832477 0.25272998]]
# -----------------------
# Chay lan 32
#
# V_truoc:
# [[5.84827353 2.73025173 4.27273838 1.34289434]
#  [6.6786552  3.06449663 5.53776156 2.04062155]
#  [5.0393401  3.44535742 1.49832477 0.25272998]]
# V_sau:
# [[5.84828011 2.73025468 4.27274709 1.34289852]
#  [6.67866107 3.06449889 5.53776987 2.04062607]
#  [5.03934009 3.44535711 1.49832526 0.2527302 ]]
# -----------------------
# Chay lan 33
#
# V_truoc:
# [[5.84828011 2.73025468 4.27274709 1.34289852]
#  [6.67866107 3.06449889 5.53776987 2.04062607]
#  [5.03934009 3.44535711 1.49832526 0.2527302 ]]
# V_sau:
# [[5.84828465 2.73025671 4.27275309 1.3429014 ]
#  [6.67866511 3.06450045 5.53777559 2.04062919]
#  [5.03934008 3.44535689 1.4983256  0.25273035]]
# -----------------------
# Chay lan 34
#
# V_truoc:
# [[5.84828465 2.73025671 4.27275309 1.3429014 ]
#  [6.67866511 3.06450045 5.53777559 2.04062919]
#  [5.03934008 3.44535689 1.4983256  0.25273035]]
# V_sau:
# [[5.84828777 2.73025811 4.27275722 1.34290339]
#  [6.67866789 3.06450152 5.53777953 2.04063133]
#  [5.03934007 3.44535674 1.49832583 0.25273045]]
# -----------------------
# Chay lan 35
#
# V_truoc:
# [[5.84828777 2.73025811 4.27275722 1.34290339]
#  [6.67866789 3.06450152 5.53777953 2.04063133]
#  [5.03934007 3.44535674 1.49832583 0.25273045]]
# V_sau:
# [[5.84828993 2.73025907 4.27276007 1.34290475]
#  [6.67866981 3.06450226 5.53778225 2.04063281]
#  [5.03934007 3.44535664 1.49832599 0.25273052]]
# -----------------------
# Chay lan 36
#
# V_truoc:
# [[5.84828993 2.73025907 4.27276007 1.34290475]
#  [6.67866981 3.06450226 5.53778225 2.04063281]
#  [5.03934007 3.44535664 1.49832599 0.25273052]]
# V_sau:
# [[5.84829141 2.73025973 4.27276203 1.34290569]
#  [6.67867113 3.06450277 5.53778412 2.04063382]
#  [5.03934007 3.44535657 1.4983261  0.25273057]]
# -----------------------
# Chay lan 37
#
# V_truoc:
# [[5.84829141 2.73025973 4.27276203 1.34290569]
#  [6.67867113 3.06450277 5.53778412 2.04063382]
#  [5.03934007 3.44535657 1.4983261  0.25273057]]
# V_sau:
# [[5.84829243 2.73026019 4.27276338 1.34290634]
#  [6.67867204 3.06450312 5.5377854  2.04063452]
#  [5.03934007 3.44535652 1.49832618 0.25273061]]
# -----------------------
# Chay lan 38
#
# V_truoc:
# [[5.84829243 2.73026019 4.27276338 1.34290634]
#  [6.67867204 3.06450312 5.5377854  2.04063452]
#  [5.03934007 3.44535652 1.49832618 0.25273061]]
# V_sau:
# [[5.84829313 2.7302605  4.27276431 1.34290679]
#  [6.67867266 3.06450336 5.53778629 2.04063501]
#  [5.03934007 3.44535649 1.49832623 0.25273063]]
#
# ------------------------------------
# Ketqua
#
# [[5.84829313 2.7302605  4.27276431 1.34290679]
#  [6.67867266 3.06450336 5.53778629 2.04063501]
#  [5.03934007 3.44535649 1.49832623 0.25273063]]

# %% [markdown]
# # **Đánh giá kết quả**

# %%
i_class = 0;
num_class =2;
count_class_cluster = np.zeros((2,c), dtype="int64")
for k in range(n):
    if k in index_x_giamsat :
        k_class = 0
    else :
        k_class = 1
    max_u = np.amax(U[k])
    index_max = np.where(U[k]== max_u )
    
    count_class_cluster[k_class][index_max] +=1
count_class_cluster
# Out:
# array([[19, 14, 17],
#        [40, 27, 33]], dtype=int64)

# %%
a1=b1=c1=d1=0.0
for i in range(num_class):
    a1+= sum ( (count_class_cluster[i]-1)*count_class_cluster[i]/2 )
    b1+= (pow(sum(count_class_cluster[i]),2) - sum(pow(count_class_cluster[i],2)) )/2
for i in range(c):
    c1+= count_class_cluster[0][i]*count_class_cluster[1][i]
    for j in range(c):
        if i != j :
            d1+=count_class_cluster[0][i]*count_class_cluster[1][j] 
            
print(a1)
print(b1)
print(c1)
print(d1)
# Out:
# 2057.0
# 4118.0
# 1699.0
# 3301.0
