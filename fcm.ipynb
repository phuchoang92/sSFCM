# %% [markdown]
# # **PreProcess**

# %% [markdown]
# ## Load Data

# %%
import pandas as pd
data = pd.read_csv('resources/iris.data', header = None)
data = data.select_dtypes(include=["float64", "int64"])
data
# Out:
#        0    1    2    3
# 0    5.1  3.5  1.4  0.2
# 1    4.9  3.0  1.4  0.2
# 2    4.7  3.2  1.3  0.2
# 3    4.6  3.1  1.5  0.2
# 4    5.0  3.6  1.4  0.2
# ..   ...  ...  ...  ...
# 145  6.7  3.0  5.2  2.3
# 146  6.3  2.5  5.0  1.9
# 147  6.5  3.0  5.2  2.0
# 148  6.2  3.4  5.4  2.3
# 149  5.9  3.0  5.1  1.8
#
# [150 rows x 4 columns]

# %%
import numpy as np
X = np.array(data)
n = X.shape[0]
p = X.shape[1]
print(X.shape)
#Maxtrix X size= n*7
X
# Out:
# (150, 4)
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.5, 4.2, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5. , 3.2, 1.2, 0.2],
#        [5.5, 3.5, 1.3, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [4.4, 3. , 1.3, 0.2],
#        [5.1, 3.4, 1.5, 0.2],
#        [5. , 3.5, 1.3, 0.3],
#        [4.5, 2.3, 1.3, 0.3],
#        [4.4, 3.2, 1.3, 0.2],
#        [5. , 3.5, 1.6, 0.6],
#        [5.1, 3.8, 1.9, 0.4],
#        [4.8, 3. , 1.4, 0.3],
#        [5.1, 3.8, 1.6, 0.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [5. , 3.3, 1.4, 0.2],
#        [7. , 3.2, 4.7, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.5, 2.3, 4. , 1.3],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [4.9, 2.4, 3.3, 1. ],
#        [6.6, 2.9, 4.6, 1.3],
#        [5.2, 2.7, 3.9, 1.4],
#        [5. , 2. , 3.5, 1. ],
#        [5.9, 3. , 4.2, 1.5],
#        [6. , 2.2, 4. , 1. ],
#        [6.1, 2.9, 4.7, 1.4],
#        [5.6, 2.9, 3.6, 1.3],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.6, 3. , 4.5, 1.5],
#        [5.8, 2.7, 4.1, 1. ],
#        [6.2, 2.2, 4.5, 1.5],
#        [5.6, 2.5, 3.9, 1.1],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.1, 2.8, 4. , 1.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.4, 2.9, 4.3, 1.3],
#        [6.6, 3. , 4.4, 1.4],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.7, 3. , 5. , 1.7],
#        [6. , 2.9, 4.5, 1.5],
#        [5.7, 2.6, 3.5, 1. ],
#        [5.5, 2.4, 3.8, 1.1],
#        [5.5, 2.4, 3.7, 1. ],
#        [5.8, 2.7, 3.9, 1.2],
#        [6. , 2.7, 5.1, 1.6],
#        [5.4, 3. , 4.5, 1.5],
#        [6. , 3.4, 4.5, 1.6],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.6, 3. , 4.1, 1.3],
#        [5.5, 2.5, 4. , 1.3],
#        [5.5, 2.6, 4.4, 1.2],
#        [6.1, 3. , 4.6, 1.4],
#        [5.8, 2.6, 4. , 1.2],
#        [5. , 2.3, 3.3, 1. ],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.7, 3. , 4.2, 1.2],
#        [5.7, 2.9, 4.2, 1.3],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.1, 2.5, 3. , 1.1],
#        [5.7, 2.8, 4.1, 1.3],
#        [6.3, 3.3, 6. , 2.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [7.1, 3. , 5.9, 2.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.5, 3. , 5.8, 2.2],
#        [7.6, 3. , 6.6, 2.1],
#        [4.9, 2.5, 4.5, 1.7],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.7, 2.5, 5.8, 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.5, 3.2, 5.1, 2. ],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.8, 3. , 5.5, 2.1],
#        [5.7, 2.5, 5. , 2. ],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.5, 3. , 5.5, 1.8],
#        [7.7, 3.8, 6.7, 2.2],
#        [7.7, 2.6, 6.9, 2.3],
#        [6. , 2.2, 5. , 1.5],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.6, 2.8, 4.9, 2. ],
#        [7.7, 2.8, 6.7, 2. ],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.7, 3.3, 5.7, 2.1],
#        [7.2, 3.2, 6. , 1.8],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.1, 3. , 4.9, 1.8],
#        [6.4, 2.8, 5.6, 2.1],
#        [7.2, 3. , 5.8, 1.6],
#        [7.4, 2.8, 6.1, 1.9],
#        [7.9, 3.8, 6.4, 2. ],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.1, 2.6, 5.6, 1.4],
#        [7.7, 3. , 6.1, 2.3],
#        [6.3, 3.4, 5.6, 2.4],
#        [6.4, 3.1, 5.5, 1.8],
#        [6. , 3. , 4.8, 1.8],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.7, 3.1, 5.6, 2.4],
#        [6.9, 3.1, 5.1, 2.3],
#        [5.8, 2.7, 5.1, 1.9],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.7, 3. , 5.2, 2.3],
#        [6.3, 2.5, 5. , 1.9],
#        [6.5, 3. , 5.2, 2. ],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.9, 3. , 5.1, 1.8]])

# %% [markdown]
# ## Generate U_ngang , V

# %%
from random import random
c=3   #value of c 
U_ngang = np.random.rand(n,c)
sum_i = np.zeros(n) 
# Doan nay lam tong u_ki <= 1 , i = 1,c 
for i in range(n):
    U_ngang[i] = U_ngang[i]/sum(U_ngang[i])*random()
    sum_i[i] = sum(U_ngang[i])
#Maxtrix U_ngang
U_ngang
# Out:
# array([[3.61847403e-01, 2.06610632e-01, 1.83736725e-01],
#        [1.34716713e-01, 1.81375911e-01, 5.23049978e-02],
#        [1.59620549e-01, 4.65257945e-02, 1.07590020e-01],
#        [2.84528428e-01, 1.63613017e-01, 4.13773175e-01],
#        [4.88268954e-01, 5.84895250e-02, 3.49028856e-01],
#        [6.10894263e-02, 1.75977794e-01, 5.09271613e-01],
#        [2.95529737e-02, 5.93069836e-01, 2.71800304e-01],
#        [1.11891024e-01, 2.08804458e-02, 9.10343721e-02],
#        [1.44303682e-01, 1.46878322e-01, 2.24815598e-01],
#        [3.49806550e-01, 2.39792675e-01, 1.25094788e-01],
#        [2.84920183e-01, 1.08675901e-01, 5.97929536e-02],
#        [3.49357235e-01, 8.05072493e-03, 4.50110538e-01],
#        [3.73422553e-02, 2.84328624e-01, 1.18687467e-01],
#        [1.71575461e-01, 1.75029801e-01, 2.36841885e-02],
#        [9.35237623e-02, 1.64790744e-01, 2.43156290e-01],
#        [8.19843540e-01, 1.56442812e-01, 2.01673243e-02],
#        [3.30099726e-02, 9.58030381e-03, 1.85357253e-02],
#        [2.96382070e-02, 4.45586003e-02, 5.13613550e-02],
#        [9.60376007e-02, 3.32141406e-02, 4.97929466e-02],
#        [1.72569815e-01, 2.51172777e-01, 2.59502932e-01],
#        [1.28996190e-01, 4.35944838e-01, 3.80467220e-01],
#        [2.96357206e-01, 4.06147605e-02, 1.25241002e-01],
#        [2.93685693e-01, 3.13705963e-01, 1.39563559e-01],
#        [7.04999373e-02, 5.00076520e-02, 4.20937778e-02],
#        [8.40057982e-02, 3.17846999e-03, 7.01657708e-02],
#        [7.13095433e-02, 2.74146310e-01, 5.64498908e-01],
#        [7.35785090e-02, 2.07608791e-01, 7.41188012e-02],
#        [3.58641303e-02, 4.67389325e-02, 4.26306513e-03],
#        [5.46492451e-02, 6.22610947e-03, 6.88207461e-03],
#        [1.61194574e-01, 4.24479017e-02, 1.19741837e-01],
#        [6.97278010e-02, 4.54420357e-02, 2.16436931e-01],
#        [6.90029131e-02, 3.09441860e-02, 4.96267584e-02],
#        [2.20570482e-01, 6.77573594e-02, 2.29497261e-01],
#        [2.81023185e-01, 3.30794809e-01, 4.50426378e-02],
#        [1.31667320e-01, 4.57201651e-01, 2.73430406e-01],
#        [1.94936932e-01, 1.42774830e-01, 4.28073938e-02],
#        [4.64716712e-02, 4.12319548e-02, 4.72490495e-01],
#        [2.73517481e-01, 1.91044040e-01, 2.91323182e-01],
#        [3.37603399e-01, 3.00872495e-01, 3.39248913e-01],
#        [1.70069758e-01, 1.44323241e-01, 1.00714512e-01],
#        [1.52760018e-01, 2.81276090e-01, 1.44774363e-01],
#        [1.68240415e-01, 1.17292742e-01, 2.32882417e-01],
#        [3.06403836e-04, 1.53655055e-02, 1.13552973e-02],
#        [1.17451788e-01, 2.66691226e-01, 5.77072302e-02],
#        [1.92079771e-01, 5.44417238e-02, 1.08190663e-01],
#        [4.59796765e-02, 5.39508197e-02, 8.33660606e-04],
#        [2.98888384e-02, 2.09821654e-02, 1.63827397e-02],
#        [6.00911895e-03, 4.11577721e-03, 6.72747025e-03],
#        [3.06453908e-01, 2.32947858e-01, 6.66878066e-02],
#        [1.50825691e-01, 3.61375843e-01, 4.51768466e-01],
#        [2.11476455e-01, 2.12953318e-01, 5.28277230e-01],
#        [3.53667057e-01, 3.50665210e-01, 4.34811511e-02],
#        [2.04020795e-01, 1.42041032e-01, 2.18248797e-02],
#        [1.97345840e-01, 2.78665746e-01, 1.60843103e-01],
#        [1.08944063e-01, 8.72012107e-03, 3.65282433e-01],
#        [2.31148002e-02, 1.23230703e-02, 2.25108815e-02],
#        [1.88676773e-01, 5.35949092e-02, 3.20547567e-02],
#        [3.53729580e-02, 2.62266292e-01, 1.00779530e-01],
#        [2.35111037e-01, 1.24352037e-01, 5.39111063e-01]])

# %%
#Maxtrix V sinh ngau nhien
V = np.random.rand(c,p)
V_truoc = V
V
# Out:
# array([[0.64281361, 0.67819051, 0.0823699 , 0.59702026],
#        [0.93796228, 0.83673313, 0.87765796, 0.56360199],
#        [0.89936118, 0.47426538, 0.51060811, 0.91106326]])

# %% [markdown]
# ## Function 4 ,6

# %%
# Tinh d_ki (trong cong thuc 6)
def d_ki(k, i):
    kq = sum(  pow(X[k] - V[i], 2) )
    return kq     
d_ki(0,0)
# Out:
# 29.722893462435795

# %%
#Cong thuc so 6

U = np.zeros((n,c))  # Maxtrix U


def cong_thuc_6(m):
    
    Z = np.zeros((n,c))
    #tu day suy ra U = U_ngang + Z ta tinh Z

    D = np.zeros((n,c))
    for k in range(n):
        for i in range(c):
            D[k][i] = pow(d_ki(k,i),1/(1-m))
            D[k] = D[k]/sum(D[k])    
     

    #Z = (1/d_ki)^1/m-1z = np.array (i = 1 ,c)
    for i in range(n) :
        Z[i] = (1 - sum_i[i])*D[i]
        
    return U_ngang+Z  # tuc la U

# %%
def cong_thuc_4(m):
    global V, V_truoc
    V_truoc = V
    print("V_truoc:")
    print(V_truoc)
    V_temp = np.zeros((c,p))
    U_temp = abs(U - U_ngang)
    U_temp = pow(U_temp,1/(m-1))
    mau_so_array= sum(U_temp.T)
    for i in range(c):
       tu_so = np.zeros(p)
       for k in range(n):
           tu_so +=U_temp[k][i] * X[k] 
       V_temp[i] = tu_so/ sum(mau_so_array)
    print("V_sau:")
    print(V_temp)
    return V_temp

# %%
def thuat_toan(epsilon,m):
    global U,V
    Epsilon = np.zeros((c,p)) + epsilon
    i=1
    while True:
        print("-----------------------\nChay lan "+ str(i)+"\n")
        i+=1
        U= cong_thuc_6(m)
        V= cong_thuc_4(m)
        delta_V = abs(V- V_truoc)
        ktra = np.less_equal(delta_V, Epsilon)
        if (np.all(ktra)):
            break
    print("\n------------------------------------\nKetqua\n")
    print(V)
    return

# %% [markdown]
# # **Main**

# %%
thuat_toan(1e-5, 2)
# Out:
# -----------------------
# Chay lan 1
#
# V_truoc:
# [[0.64281361 0.67819051 0.0823699  0.59702026]
#  [0.93796228 0.83673313 0.87765796 0.56360199]
#  [0.89936118 0.47426538 0.51060811 0.91106326]]
# V_sau:
# [[5.53748404 2.89299727 3.61426423 1.16129745]
#  [0.14827855 0.08286771 0.08346553 0.02501862]
#  [0.13741505 0.07664799 0.07766355 0.0233393 ]]
# -----------------------
# Chay lan 2
#
# V_truoc:
# [[5.53748404 2.89299727 3.61426423 1.16129745]
#  [0.14827855 0.08286771 0.08346553 0.02501862]
#  [0.13741505 0.07664799 0.07766355 0.0233393 ]]
# V_sau:
# [[5.61920236 2.93916483 3.65898743 1.17450746]
#  [0.10113594 0.0561714  0.05779011 0.01746052]
#  [0.10283934 0.05717675 0.05861577 0.01768739]]
# -----------------------
# Chay lan 3
#
# V_truoc:
# [[5.61920236 2.93916483 3.65898743 1.17450746]
#  [0.10113594 0.0561714  0.05779011 0.01746052]
#  [0.10283934 0.05717675 0.05861577 0.01768739]]
# V_sau:
# [[5.62202865 2.94077647 3.66049709 1.17494718]
#  [0.09953073 0.05525669 0.05693109 0.01721005]
#  [0.10161826 0.05647982 0.05796514 0.01749815]]
# -----------------------
# Chay lan 4
#
# V_truoc:
# [[5.62202865 2.94077647 3.66049709 1.17494718]
#  [0.09953073 0.05525669 0.05693109 0.01721005]
#  [0.10161826 0.05647982 0.05796514 0.01749815]]
# V_sau:
# [[5.62212505 2.94083145 3.66054855 1.17496217]
#  [0.09947689 0.05522601 0.05690228 0.01720165]
#  [0.1015757  0.05645552 0.05794249 0.01749156]]
# -----------------------
# Chay lan 5
#
# V_truoc:
# [[5.62212505 2.94083145 3.66054855 1.17496217]
#  [0.09947689 0.05522601 0.05690228 0.01720165]
#  [0.1015757  0.05645552 0.05794249 0.01749156]]
# V_sau:
# [[5.62212833 2.94083332 3.6605503  1.17496268]
#  [0.09947509 0.05522498 0.05690131 0.01720136]
#  [0.10157422 0.05645467 0.0579417  0.01749133]]
#
# ------------------------------------
# Ketqua
#
# [[5.62212833 2.94083332 3.6605503  1.17496268]
#  [0.09947509 0.05522498 0.05690131 0.01720136]
#  [0.10157422 0.05645467 0.0579417  0.01749133]]
