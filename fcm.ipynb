# %%
import pandas as pd
data = pd.read_csv('abalone.data', header = None, usecols= [1,2,3,4,5,6,7])
data
# Out:
#           1      2      3       4       5       6       7
# 0     0.455  0.365  0.095  0.5140  0.2245  0.1010  0.1500
# 1     0.350  0.265  0.090  0.2255  0.0995  0.0485  0.0700
# 2     0.530  0.420  0.135  0.6770  0.2565  0.1415  0.2100
# 3     0.440  0.365  0.125  0.5160  0.2155  0.1140  0.1550
# 4     0.330  0.255  0.080  0.2050  0.0895  0.0395  0.0550
# ...     ...    ...    ...     ...     ...     ...     ...
# 4172  0.565  0.450  0.165  0.8870  0.3700  0.2390  0.2490
# 4173  0.590  0.440  0.135  0.9660  0.4390  0.2145  0.2605
# 4174  0.600  0.475  0.205  1.1760  0.5255  0.2875  0.3080
# 4175  0.625  0.485  0.150  1.0945  0.5310  0.2610  0.2960
# 4176  0.710  0.555  0.195  1.9485  0.9455  0.3765  0.4950
#
# [4177 rows x 7 columns]

# %%
import numpy as np
X = np.array(data)
n = int(X.size/7)
print(X.shape)
#Maxtrix X size= n*7
X
# Out:
# (4177, 7)
# array([[0.455 , 0.365 , 0.095 , ..., 0.2245, 0.101 , 0.15  ],
#        [0.35  , 0.265 , 0.09  , ..., 0.0995, 0.0485, 0.07  ],
#        [0.53  , 0.42  , 0.135 , ..., 0.2565, 0.1415, 0.21  ],
#        ...,
#        [0.6   , 0.475 , 0.205 , ..., 0.5255, 0.2875, 0.308 ],
#        [0.625 , 0.485 , 0.15  , ..., 0.531 , 0.261 , 0.296 ],
#        [0.71  , 0.555 , 0.195 , ..., 0.9455, 0.3765, 0.495 ]])

# %%
from random import random
c=3   #value of c 
U_ngang = np.random.rand(n,c)
sum_i = np.zeros(n) 
# Doan nay lam tong u_ki <= 1 , i = 1,c 
for i in range(n):
    U_ngang[i] = U_ngang[i]/sum(U_ngang[i])*random()
    sum_i[i] = sum(U_ngang[i])
#Maxtrix U_ngang
U_ngang
# Out:
# array([[0.02213092, 0.03456711, 0.05630603],
#        [0.30984639, 0.26491879, 0.11463777],
#        [0.07450217, 0.03601673, 0.07958938],
#        ...,
#        [0.3702461 , 0.03999667, 0.38302253],
#        [0.01138063, 0.00538919, 0.00213199],
#        [0.30415853, 0.16962268, 0.37716865]])

# %%
V = np.random.rand(c,7)
#Maxtrix V sinh ngau nhien
V
# Out:
# array([[0.02286223, 0.02007529, 0.30471944, 0.68901665, 0.99820662,
#         0.38532274, 0.40924518],
#        [0.01089059, 0.1988155 , 0.37028888, 0.26166055, 0.63595368,
#         0.72471176, 0.85257657],
#        [0.2385002 , 0.39101992, 0.47329161, 0.16587969, 0.09538675,
#         0.07694023, 0.1567774 ]])

# %%
# Tinh d_ki (trong cong thuc 6)
def d_ki(k, i):
    kq = sum(  pow(X[k] - V[i], 2) )
    return kq     
d_ki(0,0)
# Out:
# 1.1269985942149359

# %%
#Cong thuc so 6

U = np.zeros((n,c))  # Maxtrix U


def cong_thuc_6(m):
    
    Z = np.zeros((n,c))
    #tu day suy ra U = U_ngang + Z ta tinh Z

    D = np.zeros((n,c))
    for k in range(n):
        for i in range(c):
            D[k][i] = pow(d_ki(k,i),1/(1-m))
            D[k] = D[k]/sum(D[k])    
     

    #Z = (1/d_ki)^1/m-1z = np.array (i = 1 ,c)
    for i in range(n) :
        Z[i] = (1 - sum_i[i])*D[i]
        
    return U_ngang+Z  # tuc la U

# %%
U-U_ngang
# Out:
# array([[-0.02213092, -0.03456711, -0.05630603],
#        [-0.30984639, -0.26491879, -0.11463777],
#        [-0.07450217, -0.03601673, -0.07958938],
#        ...,
#        [-0.3702461 , -0.03999667, -0.38302253],
#        [-0.01138063, -0.00538919, -0.00213199],
#        [-0.30415853, -0.16962268, -0.37716865]])

# %%
def cong_thuc_4(m):
    V_temp = np.zeros((c,7))
    U_temp = abs(U - U_ngang)
    U_temp = pow(U_temp,1/(m-1))
    mau_so_array= sum(U_temp.T)
    for i in range(c):
       tu_so = np.zeros(7)
       for k in range(n):
           tu_so +=U_temp[k][i] * X[k] 
       V_temp[i] = tu_so/ sum(mau_so_array)
    return V_temp

# %%
# test vong lap khoang 50 lan thay V cung hoi tu ~ ma doan nay chac phai test lai
for i in range(50):
    U= cong_thuc_6(2)
    V= cong_thuc_4(2)
    print(V)
# Out:
# [[0.15727107 0.12314966 0.04251846 0.29577707 0.12868833 0.06452425
#   0.08389695]
#  [0.08270596 0.06465356 0.02221383 0.14379208 0.06238702 0.03148302
#   0.04125714]
#  [0.28268371 0.21895381 0.07441896 0.38181216 0.16483709 0.08342564
#   0.11191703]]
# [[0.11610895 0.09128469 0.03183602 0.24167109 0.10529954 0.05271962
#   0.0680662 ]
#  [0.0644087  0.05036624 0.01735473 0.11319471 0.04910272 0.02477344
#   0.03243726]
#  [0.34214308 0.2651061  0.0899605  0.46651551 0.20151018 0.10193983
#   0.13656766]]
# [[0.1038877  0.08170297 0.02855143 0.2199536  0.09589831 0.04796044
#   0.06182336]
#  [0.05265218 0.04111426 0.0141888  0.09233715 0.04009254 0.02020476
#   0.02639961]
#  [0.36612086 0.2839398  0.09641103 0.50909056 0.21992159 0.1112677
#   0.14884815]]
# [[0.09828225 0.07729996 0.02703947 0.20955996 0.09139634 0.04568174
#   0.05884549]
#  [0.04817657 0.03756569 0.01296543 0.08323546 0.0361558  0.01820867
#   0.02378655]
# ...
